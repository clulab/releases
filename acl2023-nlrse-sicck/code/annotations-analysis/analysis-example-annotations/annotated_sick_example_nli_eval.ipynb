# %% [markdown]
# ### NLI system results & Evaluation
#
# - Approach for NLI systems' predictions, as suggested by Mihai:
#
#   1. Run NLI with original data.
#   2. If top prediction is other than Neutral, choose top and STOP.
#   3. If Neutral, run NLI in the other direction. If top prediction if
#    Entailment, report RE; otherwise Neutral.
#
# Sushma Anand Akoju, Email: sushmaakoju@arizona.edu

# %%
! pip install sentence-transformers allennlp-models
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 KB 7.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting allennlp-models
#   Downloading allennlp_models-2.10.1-py3-none-any.whl (464 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 464.5/464.5 KB 36.8 MB/s eta 0:00:00
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 83.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from sentence-transformers) (4.64.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from sentence-transformers) (1.13.0+cu116)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.8/dist-packages (from sentence-transformers) (0.14.0+cu116)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from sentence-transformers) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from sentence-transformers) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from sentence-transformers) (1.7.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (from sentence-transformers) (3.7)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 56.1 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 KB 22.8 MB/s eta 0:00:00
# Collecting allennlp<2.11,>=2.10.1
#   Downloading allennlp-2.10.1-py3-none-any.whl (730 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 730.2/730.2 KB 42.2 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.8.0-py3-none-any.whl (452 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.9/452.9 KB 33.6 MB/s eta 0:00:00
# Collecting word2number>=1.1
#   Downloading word2number-1.1.zip (9.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 KB 7.5 MB/s eta 0:00:00
# Collecting py-rouge==1.1
#   Downloading py_rouge-1.1-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 KB 8.6 MB/s eta 0:00:00
# Collecting torch>=1.6.0
#   Downloading torch-1.12.1-cp38-cp38-manylinux1_x86_64.whl (776.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.3/776.3 MB 1.9 MB/s eta 0:00:00
# Collecting conllu==4.4.2
#   Downloading conllu-4.4.2-py2.py3-none-any.whl (15 kB)
# Collecting fairscale==0.4.6
#   Downloading fairscale-0.4.6.tar.gz (248 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 248.2/248.2 KB 33.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pytest>=6.2.5
#   Downloading pytest-7.2.0-py3-none-any.whl (316 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.8/316.8 KB 38.1 MB/s eta 0:00:00
# Collecting spacy<3.4,>=2.1.0
#   Downloading spacy-3.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 74.0 MB/s eta 0:00:00
# Collecting cached-path<1.2.0,>=1.1.3
#   Downloading cached_path-1.1.6-py3-none-any.whl (26 kB)
# Requirement already satisfied: protobuf<4.0.0,>=3.12.0 in /usr/local/lib/python3.8/dist-packages (from allennlp<2.11,>=2.10.1->allennlp-models) (3.19.6)
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 KB 44.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting jsonnet>=0.10.0
#   Downloading jsonnet-0.19.1.tar.gz (593 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 593.6/593.6 KB 41.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting h5py>=3.6.0
#   Downloading h5py-3.7.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 88.0 MB/s eta 0:00:00
# Collecting base58>=2.1.1
#   Downloading base58-2.1.1-py3-none-any.whl (5.6 kB)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.20.1-py3-none-any.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 83.3 MB/s eta 0:00:00
# Collecting filelock<3.8,>=3.3
#   Downloading filelock-3.7.1-py3-none-any.whl (10 kB)
# Collecting torchvision
#   Downloading torchvision-0.13.1-cp38-cp38-manylinux1_x86_64.whl (19.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 23.1 MB/s eta 0:00:00
# Requirement already satisfied: more-itertools>=8.12.0 in /usr/local/lib/python3.8/dist-packages (from allennlp<2.11,>=2.10.1->allennlp-models) (9.0.0)
# Collecting requests>=2.28
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 10.4 MB/s eta 0:00:00
# Collecting tensorboardX>=1.2
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 KB 21.5 MB/s eta 0:00:00
# Requirement already satisfied: traitlets>5.1.1 in /usr/local/lib/python3.8/dist-packages (from allennlp<2.11,>=2.10.1->allennlp-models) (5.7.1)
# Collecting lmdb>=1.2.1
#   Downloading lmdb-1.4.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (306 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.1/306.1 KB 18.0 MB/s eta 0:00:00
# Collecting termcolor==1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: dill>=0.3.4 in /usr/local/lib/python3.8/dist-packages (from allennlp<2.11,>=2.10.1->allennlp-models) (0.3.6)
# Collecting wandb<0.13.0,>=0.10.0
#   Downloading wandb-0.12.21-py2.py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 60.4 MB/s eta 0:00:00
# Requirement already satisfied: typer>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from allennlp<2.11,>=2.10.1->allennlp-models) (0.7.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk->sentence-transformers) (2022.6.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk->sentence-transformers) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk->sentence-transformers) (7.1.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from torchvision->sentence-transformers) (7.1.2)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 93.8 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.8/dist-packages (from datasets->allennlp-models) (2022.11.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from datasets->allennlp-models) (1.3.5)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.8/dist-packages (from datasets->allennlp-models) (9.0.0)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 KB 18.2 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from datasets->allennlp-models) (3.8.3)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py38-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 KB 22.8 MB/s eta 0:00:00
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.8/dist-packages (from ftfy->allennlp-models) (0.2.5)
# Collecting rich<13.0,>=12.1
#   Downloading rich-12.6.0-py3-none-any.whl (237 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.5/237.5 KB 31.0 MB/s eta 0:00:00
# Requirement already satisfied: google-cloud-storage<3.0,>=1.32.0 in /usr/local/lib/python3.8/dist-packages (from cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp-models) (2.7.0)
# Collecting boto3<2.0,>=1.0
#   Downloading boto3-1.26.43-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.7/132.7 KB 12.3 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 KB 24.7 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets->allennlp-models) (2.1.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets->allennlp-models) (22.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets->allennlp-models) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets->allennlp-models) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets->allennlp-models) (6.0.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets->allennlp-models) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets->allennlp-models) (4.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers) (3.0.9)
# Collecting pluggy<2.0,>=0.12
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from pytest>=6.2.5->allennlp<2.11,>=2.10.1->allennlp-models) (2.0.1)
# Collecting exceptiongroup>=1.0.0rc8
#   Downloading exceptiongroup-1.1.0-py3-none-any.whl (14 kB)
# Collecting iniconfig
#   Downloading iniconfig-1.1.1-py2.py3-none-any.whl (5.0 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.28->allennlp<2.11,>=2.10.1->allennlp-models) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.28->allennlp<2.11,>=2.10.1->allennlp-models) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.28->allennlp<2.11,>=2.10.1->allennlp-models) (1.24.3)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.13-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 14.9 MB/s eta 0:00:00
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp-models) (2.0.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp-models) (2.11.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp-models) (1.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp-models) (0.7.9)
# Collecting thinc<8.1.0,>=8.0.14
#   Downloading thinc-8.0.17-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (671 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 671.1/671.1 KB 45.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp-models) (3.0.10)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp-models) (3.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp-models) (3.0.8)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp-models) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp-models) (6.3.0)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp38-cp38-manylinux2014_x86_64.whl (13.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 85.9 MB/s eta 0:00:00
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp-models) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp-models) (2.4.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp-models) (1.0.9)
# Collecting typer>=0.4.1
#   Downloading typer-0.4.2-py3-none-any.whl (27 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp-models) (57.4.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp-models) (2.0.8)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.8/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp<2.11,>=2.10.1->allennlp-models) (2.3)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.8/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp<2.11,>=2.10.1->allennlp-models) (1.15.0)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.11-py3-none-any.whl (10 kB)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.12.1-py2.py3-none-any.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.3/174.3 KB 27.9 MB/s eta 0:00:00
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.30-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 KB 27.9 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp<2.11,>=2.10.1->allennlp-models) (5.4.8)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets->allennlp-models) (2022.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets->allennlp-models) (2.8.2)
# Collecting botocore<1.30.0,>=1.29.43
#   Downloading botocore-1.29.43-py3-none-any.whl (10.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 92.4 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 KB 12.6 MB/s eta 0:00:00
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.8/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp-models) (2.3.2)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp-models) (2.4.0)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /usr/local/lib/python3.8/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp-models) (2.15.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.8/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp-models) (2.11.0)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 KB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.8/dist-packages (from rich<13.0,>=12.1->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp-models) (2.6.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp-models) (2.0.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.8/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp-models) (1.57.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp-models) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp-models) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp-models) (0.2.8)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.8/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp-models) (1.5.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp-models) (0.4.8)
# Building wheels for collected packages: sentence-transformers, fairscale, termcolor, word2number, jsonnet, sacremoses, pathtools
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=2701e1350a92995897e936daaef0238e14d80eae955a8cbb7ce88354c725ef7c
#   Stored in directory: /root/.cache/pip/wheels/5e/6f/8c/d88aec621f3f542d26fac0342bef5e693335d125f4e54aeffe
#   Building wheel for fairscale (pyproject.toml) ... done
#   Created wheel for fairscale: filename=fairscale-0.4.6-py3-none-any.whl size=307251 sha256=d5f3351aee37efad3ddfc9461a68edf327774bf69a1250ef8f84b57792cd0e8d
#   Stored in directory: /root/.cache/pip/wheels/77/4c/a4/f6c0eec2ec5c8ffca075e62b0329801f862e1f1b71422f456b
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4849 sha256=d5053e42d68ca4bd1929efe7c2f264c8ed00653bc8b4f420365c5eb6d7080587
#   Stored in directory: /root/.cache/pip/wheels/a0/16/9c/5473df82468f958445479c59e784896fa24f4a5fc024b0f501
#   Building wheel for word2number (setup.py) ... done
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5582 sha256=276d19bbf8a1d8f523b843808d77400fe5b7c54599be19840cb51eb774e70e61
#   Stored in directory: /root/.cache/pip/wheels/cb/f3/5a/d88198fdeb46781ddd7e7f2653061af83e7adb2a076d8886d6
#   Building wheel for jsonnet (setup.py) ... done
#   Created wheel for jsonnet: filename=jsonnet-0.19.1-cp38-cp38-linux_x86_64.whl size=3996093 sha256=8a6534a9f44f2fe7af9dc583d3cff205efa58c1f712382ffa78de5c7189b8678
#   Stored in directory: /root/.cache/pip/wheels/64/ec/56/de861aae102c449ade2378772abbf9eb7e9acfe9a80f3e6036
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=a6e2c67de026ee5c72ce85ed6d6b0bef72760da9758483c22e5f0b2ed4f7dd73
#   Stored in directory: /root/.cache/pip/wheels/82/ab/9b/c15899bf659ba74f623ac776e861cf2eb8608c1825ddec66a4
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=6cf751632e278115fd25229a1efa8684cec2ca132550dc3f4964b9732124ad2b
#   Stored in directory: /root/.cache/pip/wheels/4c/8e/7e/72fbc243e1aeecae64a96875432e70d4e92f3d2d18123be004
# Successfully built sentence-transformers fairscale termcolor word2number jsonnet sacremoses pathtools
# Installing collected packages: word2number, tokenizers, termcolor, sentencepiece, py-rouge, pathtools, lmdb, jsonnet, iniconfig, commonmark, xxhash, urllib3, typer, torch, tensorboardX, smmap, shortuuid, setproctitle, sacremoses, rich, pydantic, pluggy, multiprocess, jmespath, h5py, ftfy, filelock, exceptiongroup, docker-pycreds, conllu, base58, thinc, sentry-sdk, requests, pytest, gitdb, fairscale, botocore, torchvision, spacy, s3transfer, responses, huggingface-hub, GitPython, wandb, transformers, datasets, boto3, sentence-transformers, cached-path, allennlp, allennlp-models
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 2.1.1
#     Uninstalling termcolor-2.1.1:
#       Successfully uninstalled termcolor-2.1.1
#   Attempting uninstall: lmdb
#     Found existing installation: lmdb 0.99
#     Uninstalling lmdb-0.99:
#       Successfully uninstalled lmdb-0.99
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: typer
#     Found existing installation: typer 0.7.0
#     Uninstalling typer-0.7.0:
#       Successfully uninstalled typer-0.7.0
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.0+cu116
#     Uninstalling torch-1.13.0+cu116:
#       Successfully uninstalled torch-1.13.0+cu116
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.2
#     Uninstalling pydantic-1.10.2:
#       Successfully uninstalled pydantic-1.10.2
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.8.2
#     Uninstalling filelock-3.8.2:
#       Successfully uninstalled filelock-3.8.2
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.1.6
#     Uninstalling thinc-8.1.6:
#       Successfully uninstalled thinc-8.1.6
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
#   Attempting uninstall: pytest
#     Found existing installation: pytest 3.6.4
#     Uninstalling pytest-3.6.4:
#       Successfully uninstalled pytest-3.6.4
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.14.0+cu116
#     Uninstalling torchvision-0.14.0+cu116:
#       Successfully uninstalled torchvision-0.14.0+cu116
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.4.4
#     Uninstalling spacy-3.4.4:
#       Successfully uninstalled spacy-3.4.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.14.0 requires torch==1.13.0, but you have torch 1.12.1 which is incompatible.
# torchaudio 0.13.0+cu116 requires torch==1.13.0, but you have torch 1.12.1 which is incompatible.
# en-core-web-sm 3.4.1 requires spacy<3.5.0,>=3.4.0, but you have spacy 3.3.2 which is incompatible.
# Successfully installed GitPython-3.1.30 allennlp-2.10.1 allennlp-models-2.10.1 base58-2.1.1 boto3-1.26.43 botocore-1.29.43 cached-path-1.1.6 commonmark-0.9.1 conllu-4.4.2 datasets-2.8.0 docker-pycreds-0.4.0 exceptiongroup-1.1.0 fairscale-0.4.6 filelock-3.7.1 ftfy-6.1.1 gitdb-4.0.10 h5py-3.7.0 huggingface-hub-0.10.1 iniconfig-1.1.1 jmespath-1.0.1 jsonnet-0.19.1 lmdb-1.4.0 multiprocess-0.70.14 pathtools-0.1.2 pluggy-1.0.0 py-rouge-1.1 pydantic-1.8.2 pytest-7.2.0 requests-2.28.1 responses-0.18.0 rich-12.6.0 s3transfer-0.6.0 sacremoses-0.0.53 sentence-transformers-2.2.2 sentencepiece-0.1.97 sentry-sdk-1.12.1 setproctitle-1.3.2 shortuuid-1.0.11 smmap-5.0.0 spacy-3.3.2 tensorboardX-2.5.1 termcolor-1.1.0 thinc-8.0.17 tokenizers-0.12.1 torch-1.12.1 torchvision-0.13.1 transformers-4.20.1 typer-0.4.2 urllib3-1.26.13 wandb-0.12.21 word2number-1.1 xxhash-3.2.0

# %%
# !pip install pycm==3.7
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pycm==3.7
#   Downloading pycm-3.7-py2.py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 KB 9.5 MB/s eta 0:00:00
# Collecting art>=1.8
#   Downloading art-5.8-py2.py3-none-any.whl (595 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 595.7/595.7 KB 36.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from pycm==3.7) (1.21.6)
# Installing collected packages: art, pycm
# Successfully installed art-5.8 pycm-3.7

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/natural-logic/final-datasets/'
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/natural-logic/final-datasets
# /content/drive/MyDrive/Colab Notebooks/natural-logic/final-datasets

# %%
import pandas as pd
import os

path = "/content/drive/MyDrive/Colab Notebooks/natural-logic/final-datasets/block-wise-data/blocks-dec26/data"
filepath = os.path.join(path,'example_annotations_gt.xlsx')
round1 = pd.read_excel(filepath, sheet_name="round1")
round1 = round1.rename(columns={'Mihai\'s Labels':"M",
       'Eduardo\'s label':"E", 'Robert\'s labels':"R", 'Haris\'s labels':"H",
       'Sushma\'s labels':"S"})
round1['SICK_id'] = 129
round1 = round1.drop(columns=['Unnamed: 0'])
round1.head()
# Out:
#                                Premise                       Hypothesis  \
# 0     an old man is sitting in a field      a man is sitting in a field
# 1  every old man is sitting in a field      a man is sitting in a field
# 2     an old man is sitting in a field  every man is sitting in a field
# 3  every old man is sitting in a field  every man is sitting in a field
# 4   some old man is sitting in a field      a man is sitting in a field
#
#   Modifier Premise/Hypothesis/Both Part of Premise/Hypothesis Modified   M  \
# 0     NONE                    NONE                                NONE  FE
# 1    every                 premise                             subject  FE
# 2    every              hypothesis                             subject  RE
# 3    every                    Both                             subject  RE
# 4     some                 premise                             subject  FE
#
#              E   R   H   S Ground Truth  SICK_id
# 0           FE  FE  FE  FE           FE      129
# 1           FE  FE  FE  FE           FE      129
# 2           RE  RE  RE  RE           RE      129
# 3           RE  RE  RE  RE           RE      129
# 4  Equivalence  FE  FE  FE           FE      129

# %%
round1.columns
# Out:
# Index(['Unnamed: 0', 'Premise', 'Hypothesis', 'Modifier',
#        'Premise/Hypothesis/Both', 'Part of Premise/Hypothesis Modified', 'M',
#        'E', 'R', 'H', 'S', 'Ground Truth', 'SICK_id'],
#       dtype='object')

# %%
round2 = pd.read_excel(filepath, sheet_name="round2")
round2 = round2.rename(columns={'Mihai\'s Labels':"M",
       'Eduardo\'s label':"E", 'Robert\'s labels':"R", 'Haris\'s labels':"H",
       'Sushma\'s labels':"S"})
round2['SICK_id'] = 167
round2 = round2.drop(columns=['Unnamed: 0'])
round2.head()
# Out:
#                            Premise                         Hypothesis  \
# 0      a boy is hitting a baseball      a child is hitting a baseball
# 1  every boy is hitting a baseball      a child is hitting a baseball
# 2      a boy is hitting a baseball  every child is hitting a baseball
# 3  every boy is hitting a baseball  every child is hitting a baseball
# 4   some boy is hitting a baseball      a child is hitting a baseball
#
#   Modifier Premise/Hypothesis/Both Part of Premise/Hypothesis Modified   M  \
# 0     NONE                    NONE                                NONE  FE
# 1    every                 Premise                             Subject  FE
# 2    every              Hypothesis                             Subject  RE
# 3    every                    Both                             Subject  RE
# 4     some                 Premise                             Subject  FE
#
#          E   R   H   S Ground Truth  SICK_id
# 0       FE  FE  FE  FE           FE      167
# 1  Neutral  FE  FE  FE           FE      167
# 2  Neutral  RE  RE  RE           RE      167
# 3  Neutral  RE  RE  FE           RE      167
# 4       FE  FE  FE  FE           FE      167

# %%
round3 = pd.read_excel(filepath, sheet_name="round3")
round3['SICK_id'] = round3['SICK_id'].astype('int')
round3.head()
# Out:
#    SICK_id                                     Premise  \
# 0      129            an old man is sitting in a field
# 1      129       an old man is sitting in a good field
# 2      129            an old man is sitting in a field
# 3      129       an old man is sitting in a good field
# 4      129  an old man is sitting in all but one field
#
#                          Hypothesis     Modifier Premise/Hypothesis/Both  \
# 0     a man is sitting in a field\n         NONE                    NONE
# 1     a man is sitting in a field\n         good                 Premise
# 2  a man is sitting in a good field         good              Hypothesis
# 3  a man is sitting in a good field         good                    Both
# 4     a man is sitting in a field\n  all but one                 Premise
#
#   Part of Premise/Hypothesis Modified        M        E        R        H  \
# 0                                NONE       FE       FE       FE       FE
# 1                              Object       FE       FE       FE       FE
# 2                              Object  Neutral  Neutral  Neutral  Neutral
# 3                              Object       FE       FE       FE       FE
# 4                              Object  Neutral       FE       FE       FE
#
#          S Ground Truth
# 0       FE           FE
# 1       FE           FE
# 2  Neutral      Neutral
# 3       FE           FE
# 4  Neutral           FE

# %%
pd.concat([round1, round2, round3]).shape, round1.shape, round2.shape, round3.shape
# Out:
# ((122, 12), (35, 12), (50, 12), (37, 12))

# %%
label_map = {'FE':1, 'RE':2, 'Negation':3, 'Neutral':4,'Alternation':5, 'Cover':6,'Equivalence':7}

# %%
# round1['label'] = round1['label'].map(label_map)
# round2['label'] = round2['label'].map(label_map)

# %%
round1.columns
# Out:
# Index(['Premise', 'Hypothesis', 'Modifier', 'Premise/Hypothesis/Both',
#        'Part of Premise/Hypothesis Modified', 'M', 'E', 'R', 'H', 'S',
#        'Ground Truth', 'SICK_id'],
#       dtype='object')

# %%
set_129 = pd.concat([round1, round2, round3])
set_129.head()
# Out:
#                                Premise                       Hypothesis  \
# 0     an old man is sitting in a field      a man is sitting in a field
# 1  every old man is sitting in a field      a man is sitting in a field
# 2     an old man is sitting in a field  every man is sitting in a field
# 3  every old man is sitting in a field  every man is sitting in a field
# 4   some old man is sitting in a field      a man is sitting in a field
#
#   Modifier Premise/Hypothesis/Both Part of Premise/Hypothesis Modified   M  \
# 0     NONE                    NONE                                NONE  FE
# 1    every                 premise                             subject  FE
# 2    every              hypothesis                             subject  RE
# 3    every                    Both                             subject  RE
# 4     some                 premise                             subject  FE
#
#              E   R   H   S Ground Truth  SICK_id
# 0           FE  FE  FE  FE           FE      129
# 1           FE  FE  FE  FE           FE      129
# 2           RE  RE  RE  RE           RE      129
# 3           RE  RE  RE  RE           RE      129
# 4  Equivalence  FE  FE  FE           FE      129

# %%
from sentence_transformers import SentenceTransformer

# %%
mod_tuple_list = [ (d['Premise'], d['Hypothesis']) for d in set_129.to_dict(orient='records')]
reversed_mod_tuple_list = [ ( d['Hypothesis'], d['Premise']) for d in set_129.to_dict(orient='records')]
reversed_mod_tuple_list[:1], mod_tuple_list[:1]
# Out:
# ([('a man is sitting in a field', 'an old man is sitting in a field')],
#  [('an old man is sitting in a field', 'a man is sitting in a field')])

# %%
len(mod_tuple_list)
# Out:
# 122

# %% [markdown]
# ## cross-encoder/nli-deberta-v3-base

# %%
from sentence_transformers import SentenceTransformer
from sentence_transformers import CrossEncoder

model = CrossEncoder('cross-encoder/nli-deberta-v3-base')
labels = []
label_mapping = ['contradiction', 'entailment', 'neutral']

for d in set_129.to_dict(orient='records'):
  forward_score = model.predict([(d['Premise'], d['Hypothesis'])]).argmax()
  rev_score = model.predict([(d['Hypothesis'], d['Premise'])]).argmax()
  if forward_score == 1 :
    labels.append("FE")
  elif forward_score == 0:
    labels.append("Negation")
  else:
    if rev_score == 1:
      labels.append("RE")
    else:
      labels.append("Neutral")
len(labels)
# Out:
# Downloading:   0%|          | 0.00/1.03k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/704M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/417 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.35M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/18.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/156 [00:00<?, ?B/s]
# /usr/local/lib/python3.8/dist-packages/transformers/convert_slow_tokenizer.py:434: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# 122

# %%
set_129['nli-deberta-v3-base'] = labels

# %%
set_129.head()
# Out:
#                                Premise                       Hypothesis  \
# 0     an old man is sitting in a field      a man is sitting in a field
# 1  every old man is sitting in a field      a man is sitting in a field
# 2     an old man is sitting in a field  every man is sitting in a field
# 3  every old man is sitting in a field  every man is sitting in a field
# 4   some old man is sitting in a field      a man is sitting in a field
#
#   Modifier Premise/Hypothesis/Both Part of Premise/Hypothesis Modified   M  \
# 0     NONE                    NONE                                NONE  FE
# 1    every                 premise                             subject  FE
# 2    every              hypothesis                             subject  RE
# 3    every                    Both                             subject  RE
# 4     some                 premise                             subject  FE
#
#              E   R   H   S Ground Truth  SICK_id nli-deberta-v3-base
# 0           FE  FE  FE  FE           FE      129                  FE
# 1           FE  FE  FE  FE           FE      129                  FE
# 2           RE  RE  RE  RE           RE      129             Neutral
# 3           RE  RE  RE  RE           RE      129                  FE
# 4  Equivalence  FE  FE  FE           FE      129                  FE

# %% [markdown]
# ## ynie/roberta-large-snli_mnli_fever_anli_R1_R2_R3-nli

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch

max_length = 256

premise = "Two women are embracing while holding to go packages."
hypothesis = "The men are fighting outside a deli."

hg_model_hub_name = "ynie/roberta-large-snli_mnli_fever_anli_R1_R2_R3-nli"
# hg_model_hub_name = "ynie/albert-xxlarge-v2-snli_mnli_fever_anli_R1_R2_R3-nli"
# hg_model_hub_name = "ynie/bart-large-snli_mnli_fever_anli_R1_R2_R3-nli"
# hg_model_hub_name = "ynie/electra-large-discriminator-snli_mnli_fever_anli_R1_R2_R3-nli"
# hg_model_hub_name = "ynie/xlnet-large-cased-snli_mnli_fever_anli_R1_R2_R3-nli"

tokenizer = AutoTokenizer.from_pretrained(hg_model_hub_name)
model = AutoModelForSequenceClassification.from_pretrained(hg_model_hub_name)

tokenized_input_seq_pair = tokenizer.encode_plus(premise, hypothesis,
                                                  max_length=max_length,
                                                  return_token_type_ids=True, truncation=True)

input_ids = torch.Tensor(tokenized_input_seq_pair['input_ids']).long().unsqueeze(0)
# remember bart doesn't have 'token_type_ids', remove the line below if you are using bart.
token_type_ids = torch.Tensor(tokenized_input_seq_pair['token_type_ids']).long().unsqueeze(0)
attention_mask = torch.Tensor(tokenized_input_seq_pair['attention_mask']).long().unsqueeze(0)

outputs = model(input_ids,
                attention_mask=attention_mask,
                token_type_ids=token_type_ids,
                labels=None)
# Note:
# "id2label": {
#     "0": "entailment",
#     "1": "neutral",
#     "2": "contradiction"
# },

predicted_probability = torch.softmax(outputs[0], dim=1)[0].tolist()  # batch_size only one

print("Premise:", premise)
print("Hypothesis:", hypothesis)
print("Entailment:", predicted_probability[0])
print("Neutral:", predicted_probability[1])
print("Contradiction:", predicted_probability[2])
# Out:
# Downloading:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/703 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/772 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Some weights of the model checkpoint at ynie/roberta-large-snli_mnli_fever_anli_R1_R2_R3-nli were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Premise: Two women are embracing while holding to go packages.
# Hypothesis: The men are fighting outside a deli.
# Entailment: 6.9011228333693e-05
# Neutral: 0.00039607766666449606
# Contradiction: 0.9995349645614624

# %%
hg_model_hub_name = "ynie/roberta-large-snli_mnli_fever_anli_R1_R2_R3-nli"
# hg_model_hub_name = "ynie/albert-xxlarge-v2-snli_mnli_fever_anli_R1_R2_R3-nli"
# hg_model_hub_name = "ynie/bart-large-snli_mnli_fever_anli_R1_R2_R3-nli"
# hg_model_hub_name = "ynie/electra-large-discriminator-snli_mnli_fever_anli_R1_R2_R3-nli"
# hg_model_hub_name = "ynie/xlnet-large-cased-snli_mnli_fever_anli_R1_R2_R3-nli"

tokenizer = AutoTokenizer.from_pretrained(hg_model_hub_name)
model = AutoModelForSequenceClassification.from_pretrained(hg_model_hub_name)
# Out:
# Some weights of the model checkpoint at ynie/roberta-large-snli_mnli_fever_anli_R1_R2_R3-nli were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def get_prob_for_this_pair(premise, hypothesis, max_length):
  tokenized_input_seq_pair = tokenizer.encode_plus(premise, hypothesis,
                                                     max_length=max_length,
                                                     return_token_type_ids=True, truncation=True)
  input_ids = torch.Tensor(tokenized_input_seq_pair['input_ids']).long().unsqueeze(0)
  # remember bart doesn't have 'token_type_ids', remove the line below if you are using bart.
  token_type_ids = torch.Tensor(tokenized_input_seq_pair['token_type_ids']).long().unsqueeze(0)
  attention_mask = torch.Tensor(tokenized_input_seq_pair['attention_mask']).long().unsqueeze(0)
  outputs = model(input_ids,
                    attention_mask=attention_mask,
                    token_type_ids=token_type_ids,
                    labels=None)
    # Note:
    # "id2label": {
    #     "0": "entailment",
    #     "1": "neutral",
    #     "2": "contradiction"
    # },

  predicted_probability = torch.softmax(outputs[0], dim=1)[0].detach().numpy()  # batch_size only one
  print("Premise:", premise)
  print("Hypothesis:", hypothesis)
  print("Entailment:", predicted_probability[0])
  print("Neutral:", predicted_probability[1])
  print("Contradiction:", predicted_probability[2])

  return predicted_probability

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch

max_length = 256
labels = []
label_mapping = ['contradiction', 'entailment', 'neutral']

for d in set_129.to_dict(orient='records'):
  forward_score = get_prob_for_this_pair(d['Premise'], d['Hypothesis'], max_length)
  rev_score = get_prob_for_this_pair(d['Hypothesis'], d['Premise'], max_length)
  this_max = forward_score.argmax()
  print(this_max)
  if this_max == 0:
    labels.append("FE")
  elif this_max == 2:
    labels.append("Negation")
  else:
    if rev_score.argmax() == 0:
      labels.append("RE")
    else:
      labels.append("Neutral")
# Out:
# Premise: an old man is sitting in a field
# Hypothesis: a man is sitting in a field
# Entailment: 0.974077
# Neutral: 0.024878338
# Contradiction: 0.0010445592
# Premise: a man is sitting in a field
# Hypothesis: an old man is sitting in a field
# Entailment: 0.003052585
# Neutral: 0.996579
# Contradiction: 0.00036835304
# 0
# Premise: every old man is sitting in a field
# Hypothesis: a man is sitting in a field
# Entailment: 0.9578277
# Neutral: 0.039522327
# Contradiction: 0.002649879
# Premise: a man is sitting in a field
# Hypothesis: every old man is sitting in a field
# Entailment: 0.0026497424
# Neutral: 0.9883718
# Contradiction: 0.008978511
# 0
# Premise: an old man is sitting in a field
# Hypothesis: every man is sitting in a field
# Entailment: 0.005110108
# Neutral: 0.8660473
# Contradiction: 0.12884259
# Premise: every man is sitting in a field
# Hypothesis: an old man is sitting in a field
# Entailment: 0.042123135
# Neutral: 0.94122946
# Contradiction: 0.016647397
# 1
# Premise: every old man is sitting in a field
# Hypothesis: every man is sitting in a field
# Entailment: 0.89299315
# Neutral: 0.086081296
# Contradiction: 0.020925635
# Premise: every man is sitting in a field
# Hypothesis: every old man is sitting in a field
# Entailment: 0.0032251433
# Neutral: 0.9957417
# Contradiction: 0.0010331541
# 0
# Premise: some old man is sitting in a field
# Hypothesis: a man is sitting in a field
# Entailment: 0.96994317
# Neutral: 0.029021181
# Contradiction: 0.0010357121
# Premise: a man is sitting in a field
# Hypothesis: some old man is sitting in a field
# Entailment: 0.01194668
# Neutral: 0.98757845
# Contradiction: 0.00047474494
# 0
# Premise: an old man is sitting in a field
# Hypothesis: some man is sitting in a field
# Entailment: 0.55089504
# Neutral: 0.4474587
# Contradiction: 0.0016462747
# Premise: some man is sitting in a field
# Hypothesis: an old man is sitting in a field
# Entailment: 0.0033374096
# Neutral: 0.99622726
# Contradiction: 0.00043542846
# 0
# Premise: some old man is sitting in a field
# Hypothesis: some man is sitting in a field
# Entailment: 0.9548856
# Neutral: 0.043824293
# Contradiction: 0.0012899945
# Premise: some man is sitting in a field
# Hypothesis: some old man is sitting in a field
# Entailment: 0.0026511312
# Neutral: 0.9970732
# Contradiction: 0.00027568848
# 0
# Premise: at least old man is sitting in a field
# Hypothesis: a man is sitting in a field
# Entailment: 0.97005904
# Neutral: 0.02872399
# Contradiction: 0.0012170172
# Premise: a man is sitting in a field
# Hypothesis: at least old man is sitting in a field
# Entailment: 0.15224016
# Neutral: 0.8463303
# Contradiction: 0.0014296023
# 0
# Premise: an old man is sitting in a field
# Hypothesis: at least man is sitting in a field
# Entailment: 0.91198367
# Neutral: 0.08671848
# Contradiction: 0.0012979
# Premise: at least man is sitting in a field
# Hypothesis: an old man is sitting in a field
# Entailment: 0.0052018976
# Neutral: 0.994327
# Contradiction: 0.00047106415
# 0
# Premise: at least old man is sitting in a field
# Hypothesis: at least man is sitting in a field
# Entailment: 0.9659732
# Neutral: 0.032445617
# Contradiction: 0.001581171
# Premise: at least man is sitting in a field
# Hypothesis: at least old man is sitting in a field
# Entailment: 0.005816025
# Neutral: 0.9937145
# Contradiction: 0.00046948498
# 0
# Premise: not every old man is sitting in a field
# Hypothesis: a man is sitting in a field
# Entailment: 0.9090703
# Neutral: 0.08248096
# Contradiction: 0.008448723
# Premise: a man is sitting in a field
# Hypothesis: not every old man is sitting in a field
# Entailment: 0.01975206
# Neutral: 0.9766644
# Contradiction: 0.003583554
# 0
# Premise: an old man is sitting in a field
# Hypothesis: not every man is sitting in a field
# Entailment: 0.21178907
# Neutral: 0.78150797
# Contradiction: 0.0067029796
# Premise: not every man is sitting in a field
# Hypothesis: an old man is sitting in a field
# Entailment: 0.00847799
# Neutral: 0.98088545
# Contradiction: 0.010636612
# 1
# Premise: not every old man is sitting in a field
# Hypothesis: not every man is sitting in a field
# Entailment: 0.97442687
# Neutral: 0.023003893
# Contradiction: 0.0025692896
# Premise: not every man is sitting in a field
# Hypothesis: not every old man is sitting in a field
# Entailment: 0.0021441106
# Neutral: 0.99751544
# Contradiction: 0.00034048635
# 0
# Premise: exactly one old man is sitting in a field
# Hypothesis: a man is sitting in a field
# Entailment: 0.974905
# Neutral: 0.023819467
# Contradiction: 0.0012754317
# Premise: a man is sitting in a field
# Hypothesis: exactly one old man is sitting in a field
# Entailment: 0.031453867
# Neutral: 0.96441966
# Contradiction: 0.0041264337
# 0
# Premise: an old man is sitting in a field
# Hypothesis: exactly one man is sitting in a field
# Entailment: 0.6674554
# Neutral: 0.3157164
# Contradiction: 0.01682823
# Premise: exactly one man is sitting in a field
# Hypothesis: an old man is sitting in a field
# Entailment: 0.0041031567
# Neutral: 0.9953922
# Contradiction: 0.0005046069
# 0
# Premise: exactly one old man is sitting in a field
# Hypothesis: exactly one man is sitting in a field
# Entailment: 0.9612778
# Neutral: 0.036798883
# Contradiction: 0.0019233064
# Premise: exactly one man is sitting in a field
# Hypothesis: exactly one old man is sitting in a field
# Entailment: 0.003102345
# Neutral: 0.99660265
# Contradiction: 0.00029503278
# 0
# Premise: all but one old man is sitting in a field
# Hypothesis: a man is sitting in a field
# Entailment: 0.9243798
# Neutral: 0.05630185
# Contradiction: 0.01931833
# Premise: a man is sitting in a field
# Hypothesis: all but one old man is sitting in a field
# Entailment: 0.018566571
# Neutral: 0.9297577
# Contradiction: 0.051675696
# 0
# Premise: an old man is sitting in a field
# Hypothesis: all but one man is sitting in a field
# Entailment: 0.12485363
# Neutral: 0.22499011
# Contradiction: 0.6501562
# Premise: all but one man is sitting in a field
# Hypothesis: an old man is sitting in a field
# Entailment: 0.0056256275
# Neutral: 0.9929501
# Contradiction: 0.0014242892
# 2
# Premise: all but one old man is sitting in a field
# Hypothesis: all but one man is sitting in a field
# Entailment: 0.9573112
# Neutral: 0.032944508
# Contradiction: 0.00974428
# Premise: all but one man is sitting in a field
# Hypothesis: all but one old man is sitting in a field
# Entailment: 0.0017559684
# Neutral: 0.997924
# Contradiction: 0.00031995017
# 0
# Premise: a bad old man is sitting in a field
# Hypothesis: a bad man is sitting in a field
# Entailment: 0.97183347
# Neutral: 0.026635213
# Contradiction: 0.0015313039
# Premise: a bad man is sitting in a field
# Hypothesis: a bad old man is sitting in a field
# Entailment: 0.007386809
# Neutral: 0.9921571
# Contradiction: 0.00045602283
# 0
# Premise: an old man is not sitting in a field
# Hypothesis: a man is sitting in a field
# Entailment: 0.029123409
# Neutral: 0.024721242
# Contradiction: 0.94615537
# Premise: a man is sitting in a field
# Hypothesis: an old man is not sitting in a field
# Entailment: 0.003329128
# Neutral: 0.148232
# Contradiction: 0.8484388
# 2
# Premise: an old man is sitting in a field
# Hypothesis: a man is not sitting in a field
# Entailment: 0.0011439803
# Neutral: 0.0020395843
# Contradiction: 0.99681646
# Premise: a man is not sitting in a field
# Hypothesis: an old man is sitting in a field
# Entailment: 0.0078083337
# Neutral: 0.27482414
# Contradiction: 0.71736753
# 2
# Premise: an old man is not sitting in a field
# Hypothesis: a man is not sitting in a field
# Entailment: 0.9732126
# Neutral: 0.025566377
# Contradiction: 0.0012210272
# Premise: a man is not sitting in a field
# Hypothesis: an old man is not sitting in a field
# Entailment: 0.0016150578
# Neutral: 0.99815613
# Contradiction: 0.00022877824
# 0
# Premise: an old man is abnormally sitting in a field
# Hypothesis: a man is sitting in a field
# Entailment: 0.971639
# Neutral: 0.027027737
# Contradiction: 0.0013333141
# Premise: a man is sitting in a field
# Hypothesis: an old man is abnormally sitting in a field
# Entailment: 0.009413418
# Neutral: 0.9873037
# Contradiction: 0.0032828632
# 0
# Premise: an old man is sitting in a field
# Hypothesis: a man is abnormally sitting in a field
# Entailment: 0.082388625
# Neutral: 0.9101285
# Contradiction: 0.007482893
# Premise: a man is abnormally sitting in a field
# Hypothesis: an old man is sitting in a field
# Entailment: 0.01027876
# Neutral: 0.9881058
# Contradiction: 0.0016154828
# 1
# Premise: an old man is abnormally sitting in a field
# Hypothesis: a man is abnormally sitting in a field
# Entailment: 0.9734335
# Neutral: 0.024755383
# Contradiction: 0.0018110842
# Premise: a man is abnormally sitting in a field
# Hypothesis: an old man is abnormally sitting in a field
# Entailment: 0.002673836
# Neutral: 0.99683493
# Contradiction: 0.000491271
# 0
# Premise: an old man is elegantly sitting in a field
# Hypothesis: a man is sitting in a field
# Entailment: 0.97254354
# Neutral: 0.026425432
# Contradiction: 0.0010310245
# Premise: a man is sitting in a field
# Hypothesis: an old man is elegantly sitting in a field
# Entailment: 0.0065587126
# Neutral: 0.99242556
# Contradiction: 0.0010157736
# 0
# Premise: an old man is sitting in a field
# Hypothesis: a man is elegantly sitting in a field
# Entailment: 0.046709917
# Neutral: 0.9491685
# Contradiction: 0.0041216253
# Premise: a man is elegantly sitting in a field
# Hypothesis: an old man is sitting in a field
# Entailment: 0.009319754
# Neutral: 0.9898887
# Contradiction: 0.00079158845
# 1
# Premise: an old man is elegantly sitting in a field
# Hypothesis: a man is elegantly sitting in a field
# Entailment: 0.97319454
# Neutral: 0.025526203
# Contradiction: 0.0012793259
# Premise: a man is elegantly sitting in a field
# Hypothesis: an old man is elegantly sitting in a field
# Entailment: 0.004362929
# Neutral: 0.99523985
# Contradiction: 0.00039724942
# 0
# Premise: an old man is always sitting in a field
# Hypothesis: a man is sitting in a field
# Entailment: 0.96795624
# Neutral: 0.030865934
# Contradiction: 0.0011777711
# Premise: a man is sitting in a field
# Hypothesis: an old man is always sitting in a field
# Entailment: 0.0025208995
# Neutral: 0.99643207
# Contradiction: 0.0010469521
# 0
# Premise: an old man is sitting in a field
# Hypothesis: a man is always sitting in a field
# Entailment: 0.008829709
# Neutral: 0.9879775
# Contradiction: 0.0031927784
# Premise: a man is always sitting in a field
# Hypothesis: an old man is sitting in a field
# Entailment: 0.009991708
# Neutral: 0.98943347
# Contradiction: 0.00057479145
# 1
# Premise: an old man is always sitting in a field
# Hypothesis: a man is always sitting in a field
# Entailment: 0.9758296
# Neutral: 0.02261868
# Contradiction: 0.0015516683
# Premise: a man is always sitting in a field
# Hypothesis: an old man is always sitting in a field
# Entailment: 0.003163064
# Neutral: 0.9965366
# Contradiction: 0.00030029926
# 0
# Premise: an old man is never sitting in a field
# Hypothesis: a man is sitting in a field
# Entailment: 0.040593017
# Neutral: 0.038892273
# Contradiction: 0.9205147
# Premise: a man is sitting in a field
# Hypothesis: an old man is never sitting in a field
# Entailment: 0.00259582
# Neutral: 0.36886215
# Contradiction: 0.62854207
# 2
# Premise: an old man is sitting in a field
# Hypothesis: a man is never sitting in a field
# Entailment: 0.0014211976
# Neutral: 0.058333676
# Contradiction: 0.94024515
# Premise: a man is never sitting in a field
# Hypothesis: an old man is sitting in a field
# Entailment: 0.007124123
# Neutral: 0.31096303
# Contradiction: 0.68191284
# 2
# Premise: an old man is never sitting in a field
# Hypothesis: a man is never sitting in a field
# Entailment: 0.97071236
# Neutral: 0.027463518
# Contradiction: 0.0018240822
# Premise: a man is never sitting in a field
# Hypothesis: an old man is never sitting in a field
# Entailment: 0.0027726616
# Neutral: 0.99694103
# Contradiction: 0.00028623824
# 0
# Premise: a boy is hitting a baseball
# Hypothesis: a child is hitting a baseball
# Entailment: 0.9620664
# Neutral: 0.03720785
# Contradiction: 0.0007257066
# Premise: a child is hitting a baseball
# Hypothesis: a boy is hitting a baseball
# Entailment: 0.021343382
# Neutral: 0.9766316
# Contradiction: 0.0020250436
# 0
# Premise: every boy is hitting a baseball
# Hypothesis: a child is hitting a baseball
# Entailment: 0.9611855
# Neutral: 0.037163742
# Contradiction: 0.0016508163
# Premise: a child is hitting a baseball
# Hypothesis: every boy is hitting a baseball
# Entailment: 0.005345446
# Neutral: 0.9358532
# Contradiction: 0.05880137
# 0
# Premise: a boy is hitting a baseball
# Hypothesis: every child is hitting a baseball
# Entailment: 0.0035049391
# Neutral: 0.9006366
# Contradiction: 0.09585848
# Premise: every child is hitting a baseball
# Hypothesis: a boy is hitting a baseball
# Entailment: 0.05313489
# Neutral: 0.79386914
# Contradiction: 0.15299603
# 1
# Premise: every boy is hitting a baseball
# Hypothesis: every child is hitting a baseball
# Entailment: 0.68542016
# Neutral: 0.2951734
# Contradiction: 0.019406425
# Premise: every child is hitting a baseball
# Hypothesis: every boy is hitting a baseball
# Entailment: 0.005000039
# Neutral: 0.9856668
# Contradiction: 0.009333156
# 0
# Premise: some boy is hitting a baseball
# Hypothesis: a child is hitting a baseball
# Entailment: 0.9581286
# Neutral: 0.041091327
# Contradiction: 0.00078010745
# Premise: a child is hitting a baseball
# Hypothesis: some boy is hitting a baseball
# Entailment: 0.05724449
# Neutral: 0.94078964
# Contradiction: 0.0019658555
# 0
# Premise: a boy is hitting a baseball
# Hypothesis: some child is hitting a baseball
# Entailment: 0.51021415
# Neutral: 0.48812857
# Contradiction: 0.0016572617
# Premise: some child is hitting a baseball
# Hypothesis: a boy is hitting a baseball
# Entailment: 0.017915646
# Neutral: 0.97980344
# Contradiction: 0.0022809263
# 0
# Premise: some boy is hitting a baseball
# Hypothesis: some child is hitting a baseball
# Entailment: 0.88681114
# Neutral: 0.112178884
# Contradiction: 0.001009969
# Premise: some child is hitting a baseball
# Hypothesis: some boy is hitting a baseball
# Entailment: 0.021591606
# Neutral: 0.9762828
# Contradiction: 0.0021256525
# 0
# Premise: at least a boy is hitting a baseball
# Hypothesis: a child is hitting a baseball
# Entailment: 0.9604665
# Neutral: 0.038823817
# Contradiction: 0.00070966186
# Premise: a child is hitting a baseball
# Hypothesis: at least a boy is hitting a baseball
# Entailment: 0.094969206
# Neutral: 0.9035679
# Contradiction: 0.0014628393
# 0
# Premise: a boy is hitting a baseball
# Hypothesis: at least a child is hitting a baseball
# Entailment: 0.967743
# Neutral: 0.031722043
# Contradiction: 0.0005349195
# Premise: at least a child is hitting a baseball
# Hypothesis: a boy is hitting a baseball
# Entailment: 0.013648833
# Neutral: 0.98459643
# Contradiction: 0.0017546779
# 0
# Premise: at least a boy is hitting a baseball
# Hypothesis: at least a child is hitting a baseball
# Entailment: 0.9445818
# Neutral: 0.05475527
# Contradiction: 0.0006628932
# Premise: at least a child is hitting a baseball
# Hypothesis: at least a boy is hitting a baseball
# Entailment: 0.007249866
# Neutral: 0.99196845
# Contradiction: 0.00078166684
# 0
# Premise: not every boy is hitting a baseball
# Hypothesis: a child is hitting a baseball
# Entailment: 0.9040608
# Neutral: 0.09095524
# Contradiction: 0.004984044
# Premise: a child is hitting a baseball
# Hypothesis: not every boy is hitting a baseball
# Entailment: 0.036747783
# Neutral: 0.94560087
# Contradiction: 0.017651295
# 0
# Premise: a boy is hitting a baseball
# Hypothesis: not every child is hitting a baseball
# Entailment: 0.10587635
# Neutral: 0.88466775
# Contradiction: 0.009455918
# Premise: not every child is hitting a baseball
# Hypothesis: a boy is hitting a baseball
# Entailment: 0.058102325
# Neutral: 0.9125123
# Contradiction: 0.029385375
# 1
# Premise: not every boy is hitting a baseball
# Hypothesis: not every child is hitting a baseball
# Entailment: 0.8797682
# Neutral: 0.11681605
# Contradiction: 0.0034156863
# Premise: not every child is hitting a baseball
# Hypothesis: not every boy is hitting a baseball
# Entailment: 0.0056597637
# Neutral: 0.99290943
# Contradiction: 0.0014307994
# 0
# Premise: exactly one boy is hitting a baseball
# Hypothesis: a child is hitting a baseball
# Entailment: 0.9761944
# Neutral: 0.023036629
# Contradiction: 0.00076901505
# Premise: a child is hitting a baseball
# Hypothesis: exactly one boy is hitting a baseball
# Entailment: 0.020922063
# Neutral: 0.96171576
# Contradiction: 0.017362162
# 0
# Premise: a boy is hitting a baseball
# Hypothesis: exactly one child is hitting a baseball
# Entailment: 0.43945158
# Neutral: 0.5170217
# Contradiction: 0.04352666
# Premise: exactly one child is hitting a baseball
# Hypothesis: a boy is hitting a baseball
# Entailment: 0.025418494
# Neutral: 0.97149855
# Contradiction: 0.0030830493
# 1
# Premise: exactly one boy is hitting a baseball
# Hypothesis: exactly one child is hitting a baseball
# Entailment: 0.9329751
# Neutral: 0.06554724
# Contradiction: 0.0014776062
# Premise: exactly one child is hitting a baseball
# Hypothesis: exactly one boy is hitting a baseball
# Entailment: 0.0074773114
# Neutral: 0.99140984
# Contradiction: 0.0011128339
# 0
# Premise: all but one boy is hitting a baseball
# Hypothesis: a child is hitting a baseball
# Entailment: 0.9543645
# Neutral: 0.042299576
# Contradiction: 0.003335896
# Premise: a child is hitting a baseball
# Hypothesis: all but one boy is hitting a baseball
# Entailment: 0.011585409
# Neutral: 0.88424915
# Contradiction: 0.104165494
# 0
# Premise: a boy is hitting a baseball
# Hypothesis: all but one child is hitting a baseball
# Entailment: 0.15584257
# Neutral: 0.186494
# Contradiction: 0.65766346
# Premise: all but one child is hitting a baseball
# Hypothesis: a boy is hitting a baseball
# Entailment: 0.015634883
# Neutral: 0.9690207
# Contradiction: 0.015344415
# 2
# Premise: all but one boy is hitting a baseball
# Hypothesis: all but one child is hitting a baseball
# Entailment: 0.9478983
# Neutral: 0.050855942
# Contradiction: 0.0012458467
# Premise: all but one child is hitting a baseball
# Hypothesis: all but one boy is hitting a baseball
# Entailment: 0.006929452
# Neutral: 0.9921113
# Contradiction: 0.00095918844
# 0
# Premise: no boy is hitting a baseball
# Hypothesis: a child is hitting a baseball
# Entailment: 0.024285845
# Neutral: 0.029883413
# Contradiction: 0.94583076
# Premise: a child is hitting a baseball
# Hypothesis: no boy is hitting a baseball
# Entailment: 0.014479655
# Neutral: 0.1734642
# Contradiction: 0.8120561
# 2
# Premise: no boy is hitting a baseball
# Hypothesis: no child is hitting a baseball
# Entailment: 0.9119916
# Neutral: 0.07857271
# Contradiction: 0.00943576
# Premise: no child is hitting a baseball
# Hypothesis: no boy is hitting a baseball
# Entailment: 0.011692836
# Neutral: 0.98604184
# Contradiction: 0.0022652936
# 0
# Premise: green boy is hitting a baseball
# Hypothesis: a child is hitting a baseball
# Entailment: 0.95138663
# Neutral: 0.047878694
# Contradiction: 0.00073474593
# Premise: a child is hitting a baseball
# Hypothesis: green boy is hitting a baseball
# Entailment: 0.008091111
# Neutral: 0.98729426
# Contradiction: 0.0046146032
# 0
# Premise: a boy is hitting a baseball
# Hypothesis: green child is hitting a baseball
# Entailment: 0.021005636
# Neutral: 0.9707127
# Contradiction: 0.008281677
# Premise: green child is hitting a baseball
# Hypothesis: a boy is hitting a baseball
# Entailment: 0.0400529
# Neutral: 0.9528665
# Contradiction: 0.007080562
# 1
# Premise: green boy is hitting a baseball
# Hypothesis: green child is hitting a baseball
# Entailment: 0.889714
# Neutral: 0.10471984
# Contradiction: 0.005566092
# Premise: green child is hitting a baseball
# Hypothesis: green boy is hitting a baseball
# Entailment: 0.042625844
# Neutral: 0.9501199
# Contradiction: 0.00725412
# 0
# Premise: happy boy is hitting a baseball
# Hypothesis: a child is hitting a baseball
# Entailment: 0.955642
# Neutral: 0.043559395
# Contradiction: 0.0007985376
# Premise: a child is hitting a baseball
# Hypothesis: happy boy is hitting a baseball
# Entailment: 0.009467356
# Neutral: 0.98912454
# Contradiction: 0.0014080855
# 0
# Premise: a boy is hitting a baseball
# Hypothesis: happy child is hitting a baseball
# Entailment: 0.023919545
# Neutral: 0.97471267
# Contradiction: 0.0013678853
# Premise: happy child is hitting a baseball
# Hypothesis: a boy is hitting a baseball
# Entailment: 0.036232382
# Neutral: 0.96085036
# Contradiction: 0.0029172555
# 1
# Premise: happy boy is hitting a baseball
# Hypothesis: happy child is hitting a baseball
# Entailment: 0.86055326
# Neutral: 0.13664734
# Contradiction: 0.0027993706
# Premise: happy child is hitting a baseball
# Hypothesis: happy boy is hitting a baseball
# Entailment: 0.07356854
# Neutral: 0.9218909
# Contradiction: 0.0045405347
# 0
# Premise: sad boy is hitting a baseball
# Hypothesis: a child is hitting a baseball
# Entailment: 0.95955133
# Neutral: 0.039510235
# Contradiction: 0.0009384328
# Premise: a child is hitting a baseball
# Hypothesis: sad boy is hitting a baseball
# Entailment: 0.0010477419
# Neutral: 0.9965031
# Contradiction: 0.002449169
# 0
# Premise: a boy is hitting a baseball
# Hypothesis: sad child is hitting a baseball
# Entailment: 0.0015312249
# Neutral: 0.9973188
# Contradiction: 0.0011499705
# Premise: sad child is hitting a baseball
# Hypothesis: a boy is hitting a baseball
# Entailment: 0.05192333
# Neutral: 0.94164336
# Contradiction: 0.0064332914
# 1
# Premise: sad boy is hitting a baseball
# Hypothesis: sad child is hitting a baseball
# Entailment: 0.8878414
# Neutral: 0.11058056
# Contradiction: 0.0015780361
# Premise: sad child is hitting a baseball
# Hypothesis: sad boy is hitting a baseball
# Entailment: 0.048834242
# Neutral: 0.9474357
# Contradiction: 0.0037300824
# 0
# Premise: good boy is hitting a baseball
# Hypothesis: a child is hitting a baseball
# Entailment: 0.9641626
# Neutral: 0.03515158
# Contradiction: 0.00068584573
# Premise: a child is hitting a baseball
# Hypothesis: good boy is hitting a baseball
# Entailment: 0.041720815
# Neutral: 0.9534997
# Contradiction: 0.004779528
# 0
# Premise: a boy is hitting a baseball
# Hypothesis: good child is hitting a baseball
# Entailment: 0.08817669
# Neutral: 0.9081349
# Contradiction: 0.0036884558
# Premise: good child is hitting a baseball
# Hypothesis: a boy is hitting a baseball
# Entailment: 0.03352533
# Neutral: 0.9645542
# Contradiction: 0.0019204223
# 1
# Premise: good boy is hitting a baseball
# Hypothesis: good child is hitting a baseball
# Entailment: 0.91401744
# Neutral: 0.08454065
# Contradiction: 0.0014419019
# Premise: good child is hitting a baseball
# Hypothesis: good boy is hitting a baseball
# Entailment: 0.082670435
# Neutral: 0.9150233
# Contradiction: 0.002306221
# 0
# Premise: bad boy is hitting a baseball
# Hypothesis: a child is hitting a baseball
# Entailment: 0.94540244
# Neutral: 0.05354131
# Contradiction: 0.001056207
# Premise: a child is hitting a baseball
# Hypothesis: bad boy is hitting a baseball
# Entailment: 0.004068239
# Neutral: 0.9888877
# Contradiction: 0.0070440876
# 0
# Premise: a boy is hitting a baseball
# Hypothesis: bad child is hitting a baseball
# Entailment: 0.00674458
# Neutral: 0.9849023
# Contradiction: 0.008353082
# Premise: bad child is hitting a baseball
# Hypothesis: a boy is hitting a baseball
# Entailment: 0.05406279
# Neutral: 0.93520516
# Contradiction: 0.010731979
# 1
# Premise: bad boy is hitting a baseball
# Hypothesis: bad child is hitting a baseball
# Entailment: 0.8860129
# Neutral: 0.11130303
# Contradiction: 0.0026840821
# Premise: bad child is hitting a baseball
# Hypothesis: bad boy is hitting a baseball
# Entailment: 0.1619711
# Neutral: 0.82676744
# Contradiction: 0.011261517
# 0
# Premise: a boy is not hitting a baseball
# Hypothesis: a child is hitting a baseball
# Entailment: 0.05263037
# Neutral: 0.045745924
# Contradiction: 0.9016237
# Premise: a child is hitting a baseball
# Hypothesis: a boy is not hitting a baseball
# Entailment: 0.0038751273
# Neutral: 0.02369171
# Contradiction: 0.97243315
# 2
# Premise: a boy is hitting a baseball
# Hypothesis: a child is not hitting a baseball
# Entailment: 0.006702129
# Neutral: 0.003612098
# Contradiction: 0.9896857
# Premise: a child is not hitting a baseball
# Hypothesis: a boy is hitting a baseball
# Entailment: 0.0027856417
# Neutral: 0.026155796
# Contradiction: 0.9710586
# 2
# Premise: a boy is not hitting a baseball
# Hypothesis: a child is not hitting a baseball
# Entailment: 0.9571038
# Neutral: 0.041975666
# Contradiction: 0.00092053815
# Premise: a child is not hitting a baseball
# Hypothesis: a boy is not hitting a baseball
# Entailment: 0.012086929
# Neutral: 0.98607844
# Contradiction: 0.0018345533
# 0
# Premise: a boy is abnormally hitting a baseball
# Hypothesis: a child is hitting a baseball
# Entailment: 0.9591367
# Neutral: 0.039999463
# Contradiction: 0.00086386036
# Premise: a child is hitting a baseball
# Hypothesis: a boy is abnormally hitting a baseball
# Entailment: 0.012601217
# Neutral: 0.975495
# Contradiction: 0.011903828
# 0
# Premise: a boy is hitting a baseball
# Hypothesis: a child is abnormally hitting a baseball
# Entailment: 0.044222187
# Neutral: 0.9397914
# Contradiction: 0.015986389
# Premise: a child is abnormally hitting a baseball
# Hypothesis: a boy is hitting a baseball
# Entailment: 0.04519161
# Neutral: 0.9492986
# Contradiction: 0.005509734
# 1
# Premise: a boy is abnormally hitting a baseball
# Hypothesis: a child is abnormally hitting a baseball
# Entailment: 0.94610554
# Neutral: 0.052853383
# Contradiction: 0.0010410968
# Premise: a child is abnormally hitting a baseball
# Hypothesis: a boy is abnormally hitting a baseball
# Entailment: 0.016385607
# Neutral: 0.98095155
# Contradiction: 0.0026627998
# 0
# Premise: a boy is elegantly hitting a baseball
# Hypothesis: a child is hitting a baseball
# Entailment: 0.9605433
# Neutral: 0.038643315
# Contradiction: 0.0008134407
# Premise: a child is hitting a baseball
# Hypothesis: a boy is elegantly hitting a baseball
# Entailment: 0.022966772
# Neutral: 0.9734795
# Contradiction: 0.0035537037
# 0
# Premise: a boy is hitting a baseball
# Hypothesis: a child is elegantly hitting a baseball
# Entailment: 0.15850012
# Neutral: 0.8373942
# Contradiction: 0.0041057053
# Premise: a child is elegantly hitting a baseball
# Hypothesis: a boy is hitting a baseball
# Entailment: 0.033792265
# Neutral: 0.9633668
# Contradiction: 0.0028409874
# 1
# Premise: a boy is elegantly hitting a baseball
# Hypothesis: a child is elegantly hitting a baseball
# Entailment: 0.95112556
# Neutral: 0.048015136
# Contradiction: 0.00085937144
# Premise: a child is elegantly hitting a baseball
# Hypothesis: a boy is elegantly hitting a baseball
# Entailment: 0.022241231
# Neutral: 0.976262
# Contradiction: 0.0014967992
# 0
# Premise: a boy is always hitting a baseball
# Hypothesis: a child is hitting a baseball
# Entailment: 0.9571135
# Neutral: 0.042077515
# Contradiction: 0.0008089655
# Premise: a child is hitting a baseball
# Hypothesis: a boy is always hitting a baseball
# Entailment: 0.010472336
# Neutral: 0.9847499
# Contradiction: 0.0047777263
# 0
# Premise: a boy is hitting a baseball
# Hypothesis: a child is always hitting a baseball
# Entailment: 0.034434497
# Neutral: 0.9583501
# Contradiction: 0.0072154165
# Premise: a child is always hitting a baseball
# Hypothesis: a boy is hitting a baseball
# Entailment: 0.071201794
# Neutral: 0.92397445
# Contradiction: 0.004823746
# 1
# Premise: a boy is always hitting a baseball
# Hypothesis: a child is always hitting a baseball
# Entailment: 0.9476441
# Neutral: 0.051528916
# Contradiction: 0.0008270485
# Premise: a child is always hitting a baseball
# Hypothesis: a boy is always hitting a baseball
# Entailment: 0.01418792
# Neutral: 0.98367715
# Contradiction: 0.0021349166
# 0
# Premise: a boy is never hitting a baseball
# Hypothesis: a child is hitting a baseball
# Entailment: 0.03157496
# Neutral: 0.022123335
# Contradiction: 0.9463017
# Premise: a child is hitting a baseball
# Hypothesis: a boy is never hitting a baseball
# Entailment: 0.00057150854
# Neutral: 0.020723343
# Contradiction: 0.97870517
# 2
# Premise: a boy is never hitting a baseball
# Hypothesis: a child is never hitting a baseball
# Entailment: 0.9524813
# Neutral: 0.046486903
# Contradiction: 0.0010318366
# Premise: a child is never hitting a baseball
# Hypothesis: a boy is never hitting a baseball
# Entailment: 0.009179746
# Neutral: 0.9892686
# Contradiction: 0.0015515593
# 0
# Premise: an old man is sitting in a field
# Hypothesis: a man is sitting in a field
#
# Entailment: 0.92193526
# Neutral: 0.07572243
# Contradiction: 0.002342217
# Premise: a man is sitting in a field
#
# Hypothesis: an old man is sitting in a field
# Entailment: 0.0044290945
# Neutral: 0.9950517
# Contradiction: 0.00051923486
# 0
# Premise: an old man is sitting in a good field
# Hypothesis: a man is sitting in a field
#
# Entailment: 0.92702043
# Neutral: 0.07055579
# Contradiction: 0.0024238357
# Premise: a man is sitting in a field
#
# Hypothesis: an old man is sitting in a good field
# Entailment: 0.0069674295
# Neutral: 0.9924672
# Contradiction: 0.00056530203
# 0
# Premise: an old man is sitting in a field
# Hypothesis: a man is sitting in a good field
# Entailment: 0.042138994
# Neutral: 0.9567078
# Contradiction: 0.001153271
# Premise: a man is sitting in a good field
# Hypothesis: an old man is sitting in a field
# Entailment: 0.005182355
# Neutral: 0.9942894
# Contradiction: 0.0005282887
# 1
# Premise: an old man is sitting in a good field
# Hypothesis: a man is sitting in a good field
# Entailment: 0.9739677
# Neutral: 0.024928534
# Contradiction: 0.0011038309
# Premise: a man is sitting in a good field
# Hypothesis: an old man is sitting in a good field
# Entailment: 0.004206042
# Neutral: 0.995394
# Contradiction: 0.0004000614
# 0
# Premise: an old man is sitting in all but one field
# Hypothesis: a man is sitting in a field
#
# Entailment: 0.80296606
# Neutral: 0.1147042
# Contradiction: 0.082329705
# Premise: a man is sitting in a field
#
# Hypothesis: an old man is sitting in all but one field
# Entailment: 0.0046963575
# Neutral: 0.98362607
# Contradiction: 0.011677601
# 0
# Premise: an old man is sitting in a field
# Hypothesis: a man is sitting in all but one field
# Entailment: 0.01186239
# Neutral: 0.948149
# Contradiction: 0.03998856
# Premise: a man is sitting in all but one field
# Hypothesis: an old man is sitting in a field
# Entailment: 0.0080066295
# Neutral: 0.99080545
# Contradiction: 0.0011879198
# 1
# Premise: an old man is sitting in all but one field
# Hypothesis: a man is sitting in all but one field
# Entailment: 0.9783741
# Neutral: 0.019923752
# Contradiction: 0.0017020978
# Premise: a man is sitting in all but one field
# Hypothesis: an old man is sitting in all but one field
# Entailment: 0.0036279222
# Neutral: 0.99598324
# Contradiction: 0.00038879167
# 0
# Premise: an old man is sitting in every field
# Hypothesis: a man is sitting in a field
#
# Entailment: 0.95126075
# Neutral: 0.04485476
# Contradiction: 0.003884433
# Premise: a man is sitting in a field
#
# Hypothesis: an old man is sitting in every field
# Entailment: 0.001957056
# Neutral: 0.9940672
# Contradiction: 0.0039757793
# 0
# Premise: an old man is sitting in a field
# Hypothesis: a man is sitting in every field
# Entailment: 0.004714611
# Neutral: 0.97785485
# Contradiction: 0.017430542
# Premise: a man is sitting in every field
# Hypothesis: an old man is sitting in a field
# Entailment: 0.0077837436
# Neutral: 0.9914028
# Contradiction: 0.000813512
# 1
# Premise: an old man is sitting in every field
# Hypothesis: a man is sitting in every field
# Entailment: 0.97936857
# Neutral: 0.019523691
# Contradiction: 0.0011077592
# Premise: a man is sitting in every field
# Hypothesis: an old man is sitting in every field
# Entailment: 0.0040167384
# Neutral: 0.99563295
# Contradiction: 0.00035022554
# 0
# Premise: an old man is sitting in a bad field
# Hypothesis: a man is sitting in a field
#
# Entailment: 0.9334583
# Neutral: 0.06354397
# Contradiction: 0.0029977437
# Premise: a man is sitting in a field
#
# Hypothesis: an old man is sitting in a bad field
# Entailment: 0.0015328641
# Neutral: 0.99764496
# Contradiction: 0.00082214235
# 0
# Premise: an old man is sitting in a field
# Hypothesis: a man is sitting in a bad field
# Entailment: 0.0037798658
# Neutral: 0.9946794
# Contradiction: 0.0015408135
# Premise: a man is sitting in a bad field
# Hypothesis: an old man is sitting in a field
# Entailment: 0.005450281
# Neutral: 0.9938407
# Contradiction: 0.00070900266
# 1
# Premise: an old man is sitting in a bad field
# Hypothesis: a man is sitting in a bad field
# Entailment: 0.97613674
# Neutral: 0.022726728
# Contradiction: 0.0011365192
# Premise: a man is sitting in a bad field
# Hypothesis: an old man is sitting in a bad field
# Entailment: 0.0029118683
# Neutral: 0.9967326
# Contradiction: 0.00035549793
# 0
# Premise: an old man is sitting in a green field
# Hypothesis: a man is sitting in a field
#
# Entailment: 0.92814386
# Neutral: 0.069724165
# Contradiction: 0.002131982
# Premise: a man is sitting in a field
#
# Hypothesis: an old man is sitting in a green field
# Entailment: 0.004282169
# Neutral: 0.9951739
# Contradiction: 0.000543896
# 0
# Premise: an old man is sitting in a field
# Hypothesis: a man is sitting in a green field
# Entailment: 0.009291473
# Neutral: 0.9901452
# Contradiction: 0.000563413
# Premise: a man is sitting in a green field
# Hypothesis: an old man is sitting in a field
# Entailment: 0.0033429628
# Neutral: 0.9962476
# Contradiction: 0.00040949072
# 1
# Premise: an old man is sitting in a green field
# Hypothesis: a man is sitting in a green field
# Entailment: 0.97290176
# Neutral: 0.025990974
# Contradiction: 0.001107244
# Premise: a man is sitting in a green field
# Hypothesis: an old man is sitting in a green field
# Entailment: 0.0030617793
# Neutral: 0.9965571
# Contradiction: 0.00038114286
# 0
# Premise: an old man is sitting in a happy field
# Hypothesis: a man is sitting in a field
#
# Entailment: 0.9194324
# Neutral: 0.07578893
# Contradiction: 0.0047786557
# Premise: a man is sitting in a field
#
# Hypothesis: an old man is sitting in a happy field
# Entailment: 0.002040283
# Neutral: 0.997129
# Contradiction: 0.0008307986
# 0
# Premise: an old man is sitting in a field
# Hypothesis: a man is sitting in a happy field
# Entailment: 0.003691629
# Neutral: 0.9944887
# Contradiction: 0.0018196335
# Premise: a man is sitting in a happy field
# Hypothesis: an old man is sitting in a field
# Entailment: 0.005753766
# Neutral: 0.9931993
# Contradiction: 0.0010469261
# 1
# Premise: an old man is sitting in a happy field
# Hypothesis: a man is sitting in a happy field
# Entailment: 0.97361237
# Neutral: 0.025255533
# Contradiction: 0.0011321238
# Premise: a man is sitting in a happy field
# Hypothesis: an old man is sitting in a happy field
# Entailment: 0.00386857
# Neutral: 0.99567896
# Contradiction: 0.00045240478
# 0
# Premise: an old man is sitting in a an abnormal field
# Hypothesis: a man is sitting in a field
#
# Entailment: 0.89799875
# Neutral: 0.097318254
# Contradiction: 0.004682988
# Premise: a man is sitting in a field
#
# Hypothesis: an old man is sitting in a an abnormal field
# Entailment: 0.010152111
# Neutral: 0.98636985
# Contradiction: 0.0034780249
# 0
# Premise: an old man is sitting in a field
# Hypothesis: a man is sitting in a an abnormal field
# Entailment: 0.047340564
# Neutral: 0.94417566
# Contradiction: 0.008483803
# Premise: a man is sitting in a an abnormal field
# Hypothesis: an old man is sitting in a field
# Entailment: 0.007199664
# Neutral: 0.99127465
# Contradiction: 0.0015256471
# 1
# Premise: an old man is sitting in a an abnormal field
# Hypothesis: a man is sitting in a an abnormal field
# Entailment: 0.9731698
# Neutral: 0.025320834
# Contradiction: 0.0015092518
# Premise: a man is sitting in a an abnormal field
# Hypothesis: an old man is sitting in a an abnormal field
# Entailment: 0.003344664
# Neutral: 0.99620193
# Contradiction: 0.00045340776
# 0
# Premise: an old man is sitting in a sad field
# Hypothesis: a man is sitting in a field
#
# Entailment: 0.9231432
# Neutral: 0.07359695
# Contradiction: 0.0032598663
# Premise: a man is sitting in a field
#
# Hypothesis: an old man is sitting in a sad field
# Entailment: 0.0011386325
# Neutral: 0.99843305
# Contradiction: 0.0004282402
# 0
# Premise: an old man is sitting in a field
# Hypothesis: a man is sitting in a sad field
# Entailment: 0.0019427217
# Neutral: 0.9976228
# Contradiction: 0.00043440473
# Premise: a man is sitting in a sad field
# Hypothesis: an old man is sitting in a field
# Entailment: 0.013147421
# Neutral: 0.9860967
# Contradiction: 0.00075586565
# 1
# Premise: an old man is sitting in a sad field
# Hypothesis: a man is sitting in a sad field
# Entailment: 0.975718
# Neutral: 0.02308305
# Contradiction: 0.0011988117
# Premise: a man is sitting in a sad field
# Hypothesis: an old man is sitting in a sad field
# Entailment: 0.0039783665
# Neutral: 0.99564457
# Contradiction: 0.00037706125
# 0
# Premise: an old man is sitting in no field
# Hypothesis: a man is sitting in a field
#
# Entailment: 0.14619863
# Neutral: 0.052564144
# Contradiction: 0.80123717
# Premise: a man is sitting in a field
#
# Hypothesis: an old man is sitting in no field
# Entailment: 0.008212274
# Neutral: 0.87218845
# Contradiction: 0.119599245
# 2
# Premise: an old man is sitting in a field
# Hypothesis: a man is sitting in no field
# Entailment: 0.00487705
# Neutral: 0.03741657
# Contradiction: 0.9577064
# Premise: a man is sitting in no field
# Hypothesis: an old man is sitting in a field
# Entailment: 0.0068155504
# Neutral: 0.9811983
# Contradiction: 0.011986082
# 2
# Premise: an old man is sitting in no field
# Hypothesis: a man is sitting in no field
# Entailment: 0.97051257
# Neutral: 0.027905468
# Contradiction: 0.0015819734
# Premise: a man is sitting in no field
# Hypothesis: an old man is sitting in no field
# Entailment: 0.00210139
# Neutral: 0.99759346
# Contradiction: 0.00030510203
# 0
# Premise: an old man is sitting in some field
# Hypothesis: a man is sitting in a field
#
# Entailment: 0.92534196
# Neutral: 0.0728452
# Contradiction: 0.0018128057
# Premise: a man is sitting in a field
#
# Hypothesis: an old man is sitting in some field
# Entailment: 0.00936392
# Neutral: 0.9900204
# Contradiction: 0.0006157223
# 0
# Premise: an old man is sitting in a field
# Hypothesis: a man is sitting in some field
# Entailment: 0.624977
# Neutral: 0.37359363
# Contradiction: 0.0014293338
# Premise: a man is sitting in some field
# Hypothesis: an old man is sitting in a field
# Entailment: 0.0037529536
# Neutral: 0.99583745
# Contradiction: 0.00040955114
# 0
# Premise: an old man is sitting in some field
# Hypothesis: a man is sitting in some field
# Entailment: 0.97282505
# Neutral: 0.02622372
# Contradiction: 0.0009513436
# Premise: a man is sitting in some field
# Hypothesis: an old man is sitting in some field
# Entailment: 0.002826311
# Neutral: 0.9968369
# Contradiction: 0.00033673833
# 0
# Premise: an old man is sitting in exactly one field
# Hypothesis: a man is sitting in a field
#
# Entailment: 0.9216044
# Neutral: 0.07434474
# Contradiction: 0.0040509254
# Premise: a man is sitting in a field
#
# Hypothesis: an old man is sitting in exactly one field
# Entailment: 0.0032348621
# Neutral: 0.9925695
# Contradiction: 0.0041956813
# 0
# Premise: an old man is sitting in a field
# Hypothesis: a man is sitting in exactly one field
# Entailment: 0.0103787305
# Neutral: 0.96741384
# Contradiction: 0.02220741
# Premise: a man is sitting in exactly one field
# Hypothesis: an old man is sitting in a field
# Entailment: 0.0051632198
# Neutral: 0.99432546
# Contradiction: 0.0005113584
# 1
# Premise: an old man is sitting in exactly one field
# Hypothesis: a man is sitting in exactly one field
# Entailment: 0.9754107
# Neutral: 0.023214646
# Contradiction: 0.001374678
# Premise: a man is sitting in exactly one field
# Hypothesis: an old man is sitting in exactly one field
# Entailment: 0.0033617427
# Neutral: 0.9963147
# Contradiction: 0.0003234796
# 0
# Premise: an old man is sitting in a an elegant field
# Hypothesis: a man is sitting in a field
#
# Entailment: 0.9168985
# Neutral: 0.08031807
# Contradiction: 0.0027833688
# Premise: a man is sitting in a field
#
# Hypothesis: an old man is sitting in a an elegant field
# Entailment: 0.0068016523
# Neutral: 0.992145
# Contradiction: 0.0010533113
# 0
# Premise: an old man is sitting in a field
# Hypothesis: a man is sitting in a an elegant field
# Entailment: 0.022936452
# Neutral: 0.9752219
# Contradiction: 0.0018417061
# Premise: a man is sitting in a an elegant field
# Hypothesis: an old man is sitting in a field
# Entailment: 0.005493283
# Neutral: 0.99383175
# Contradiction: 0.0006749421
# 1
# Premise: an old man is sitting in a an elegant field
# Hypothesis: a man is sitting in a an elegant field
# Entailment: 0.972376
# Neutral: 0.026160147
# Contradiction: 0.0014638809
# Premise: a man is sitting in a an elegant field
# Hypothesis: an old man is sitting in a an elegant field
# Entailment: 0.004696305
# Neutral: 0.99488837
# Contradiction: 0.00041537415
# 0

# %%
set_129['ynie/roberta-large-snli_mnli_fever_anli_R1_R2_R3-nli'] = labels

# %%
len(labels)
# Out:
# 122

# %%
set_129.head()
# Out:
#                                Premise                       Hypothesis  \
# 0     an old man is sitting in a field      a man is sitting in a field
# 1  every old man is sitting in a field      a man is sitting in a field
# 2     an old man is sitting in a field  every man is sitting in a field
# 3  every old man is sitting in a field  every man is sitting in a field
# 4   some old man is sitting in a field      a man is sitting in a field
#
#   Modifier Premise/Hypothesis/Both Part of Premise/Hypothesis Modified   M  \
# 0     NONE                    NONE                                NONE  FE
# 1    every                 premise                             subject  FE
# 2    every              hypothesis                             subject  RE
# 3    every                    Both                             subject  RE
# 4     some                 premise                             subject  FE
#
#              E   R   H   S Ground Truth  SICK_id nli-deberta-v3-base  \
# 0           FE  FE  FE  FE           FE      129                  FE
# 1           FE  FE  FE  FE           FE      129                  FE
# 2           RE  RE  RE  RE           RE      129             Neutral
# 3           RE  RE  RE  RE           RE      129                  FE
# 4  Equivalence  FE  FE  FE           FE      129                  FE
#
#   ynie/roberta-large-snli_mnli_fever_anli_R1_R2_R3-nli
# 0                                                 FE
# 1                                                 FE
# 2                                            Neutral
# 3                                                 FE
# 4                                                 FE

# %% [markdown]
# ## sentence-transformers/nli-roberta-large

# %%
res = CrossEncoder('sentence-transformers/nli-roberta-large').predict(mod_tuple_list)
len(res)
# Out:
# Some weights of the model checkpoint at sentence-transformers/nli-roberta-large were not used when initializing RobertaForSequenceClassification: ['pooler.dense.weight', 'pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at sentence-transformers/nli-roberta-large and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 85

# %%
res
# Out:
# array([0.42294955, 0.43844312, 0.44495082, 0.4714694 , 0.41668925,
#        0.42004484, 0.41669166, 0.42675862, 0.4299715 , 0.43694335,
#        0.40147498, 0.39460316, 0.4136719 , 0.51187176, 0.5197413 ,
#        0.5348743 , 0.43421176, 0.43630666, 0.43402466, 0.4325292 ,
#        0.4315447 , 0.4254497 , 0.43384296, 0.40797356, 0.40448922,
#        0.40461946, 0.43050262, 0.43035823, 0.4329905 , 0.39807308,
#        0.3874862 , 0.3904448 , 0.544     , 0.48888195, 0.5648749 ,
#        0.5261721 , 0.55535436, 0.559205  , 0.56525666, 0.5267037 ,
#        0.5269565 , 0.51769364, 0.5044808 , 0.5078526 , 0.48845968,
#        0.40555868, 0.43046874, 0.4368696 , 0.5473348 , 0.5585963 ,
#        0.54877496, 0.5132235 , 0.52926713, 0.48573276, 0.5264466 ,
#        0.5558931 , 0.53153104, 0.52070796, 0.52164143, 0.5276573 ,
#        0.52489513, 0.51517797, 0.54623455, 0.5472337 , 0.54755527,
#        0.52439594, 0.5169632 , 0.5120891 , 0.56850016, 0.54902667,
#        0.55903757, 0.4513551 , 0.45393333, 0.45723605, 0.549801  ,
#        0.55357486, 0.5491794 , 0.5482155 , 0.5485299 , 0.5575749 ,
#        0.51166254, 0.51520675, 0.5079865 , 0.53799075, 0.5473771 ],
#       dtype=float32)

# %% [markdown]
# ## sentence-transformers/nli-mpnet-base-v2

# %%
from transformers import AutoTokenizer, AutoModel
import torch


#Mean Pooling - Take attention mask into account for correct averaging
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0] #First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)


# Sentences we want sentence embeddings for
sentences = ['This is an example sentence', 'Each sentence is converted']

# Load model from HuggingFace Hub
tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/nli-mpnet-base-v2')
model = AutoModel.from_pretrained('sentence-transformers/nli-mpnet-base-v2')

# Tokenize sentences
encoded_input = tokenizer(sentences, padding=True, truncation=True, return_tensors='pt')

# Compute token embeddings
with torch.no_grad():
    model_output = model(**encoded_input)

# Perform pooling. In this case, max pooling.
sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])

print("Sentence embeddings:")
print(sentence_embeddings)
# Out:
# Downloading:   0%|          | 0.00/1.16k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/587 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/418M [00:00<?, ?B/s]
# Sentence embeddings:
# tensor([[ 0.1171, -0.4075,  0.0724,  ..., -0.1163,  0.0725, -0.0474],
#         [ 0.1288, -0.2126,  0.0819,  ..., -0.1885, -0.1564, -0.0603]])

# %%
sentence_embeddings.shape
# Out:
# torch.Size([2, 768])

# %% [markdown]
# ## pair-classification-decomposable-attention-elmo

# %%
from allennlp_models.pretrained import get_pretrained_models, get_tasks, load_predictor


predictor = load_predictor("pair-classification-decomposable-attention-elmo")
print(predictor.predict_json({"premise": "An interplanetary spacecraft is in orbit around a gas giant's icy moon.","hypothesis": "The spacecraft has the ability to travel between planets.",}))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# WARNING:allennlp.common.model_card:lerc is not a registered model.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /usr/local/lib/python3.8/dist-packages/spacy/util.py:837: UserWarning: [W095] Model 'en_core_web_sm' (3.4.1) was trained with spaCy v3.4 and may not be 100% compatible with the current version (3.3.2). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# {'label_logits': [1.9986499547958374, -2.6932120323181152, -0.22244024276733398], 'label_probs': [0.8947262763977051, 0.008204277604818344, 0.09706953167915344], 'h2p_attention': [[0.07183567434549332, 0.08167944103479385, 0.07109969854354858, 0.06555154174566269, 0.0640241727232933, 0.06560129672288895, 0.06374851614236832, 0.06394612044095993, 0.06341960281133652, 0.06924539059400558, 0.06312332302331924, 0.06553780287504196, 0.06363324075937271, 0.06418321281671524, 0.0633709579706192], [0.002956278622150421, 0.4930861294269562, 0.41928431391716003, 0.0037079844623804092, 0.004007070325314999, 0.006796701345592737, 0.0033320963848382235, 0.005026718135923147, 0.010420011356472969, 0.008524241857230663, 0.0036543849855661392, 0.004878420382738113, 0.029180198907852173, 0.002609934424981475, 0.0025355019606649876], [0.04962882772088051, 0.05997128412127495, 0.04268429055809975, 0.08004444092512131, 0.08457835018634796, 0.08322736620903015, 0.07323473691940308, 0.08271151036024094, 0.05420924723148346, 0.06505181640386581, 0.06234375387430191, 0.10373766720294952, 0.072382353246212, 0.04648254066705704, 0.039711859077215195], [0.028800826519727707, 0.15716852247714996, 0.06350240111351013, 0.06366211920976639, 0.08347650617361069, 0.08478954434394836, 0.06569548696279526, 0.14139549434185028, 0.0330331027507782, 0.041213519871234894, 0.05147044360637665, 0.08957389742136002, 0.05071583762764931, 0.025505265220999718, 0.019997086375951767], [0.02732984907925129, 0.06822042912244797, 0.05316372960805893, 0.07855591922998428, 0.13213691115379333, 0.21356801688671112, 0.08634578436613083, 0.07387922704219818, 0.0257396399974823, 0.03285592421889305, 0.03290335834026337, 0.07893764227628708, 0.05382440984249115, 0.02678498812019825, 0.01575413905084133], [0.03234069421887398, 0.05664703622460365, 0.03787131607532501, 0.08520698547363281, 0.13561716675758362, 0.18966388702392578, 0.06954770535230637, 0.0752338245511055, 0.04873301461338997, 0.04628453031182289, 0.044830385595560074, 0.05477036163210869, 0.05993082746863365, 0.037622272968292236, 0.02570001222193241], [0.013421257957816124, 0.07515917718410492, 0.054605063050985336, 0.025631163269281387, 0.1028328388929367, 0.5007854104042053, 0.041735630482435226, 0.03450162708759308, 0.024677127599716187, 0.02147829905152321, 0.019014505669474602, 0.029454637318849564, 0.02666294015944004, 0.018697794526815414, 0.011342507787048817], [0.016482291743159294, 0.034168537706136703, 0.023419581353664398, 0.03371327370405197, 0.1502462774515152, 0.1855880171060562, 0.19967900216579437, 0.13703212141990662, 0.020070809870958328, 0.02255702018737793, 0.02769610472023487, 0.06869325041770935, 0.05084856599569321, 0.0156509131193161, 0.01415429450571537], [0.0023430404253304005, 0.4399735927581787, 0.07884248346090317, 0.0058428640477359295, 0.005486541893333197, 0.009360420517623425, 0.008811278268694878, 0.02498748153448105, 0.0374070480465889, 0.03934892639517784, 0.008011547848582268, 0.06658387929201126, 0.26910775899887085, 0.00203495379537344, 0.0018581274198368192], [0.0618886724114418, 0.06366737186908722, 0.060257717967033386, 0.06722693145275116, 0.0708269327878952, 0.0779484212398529, 0.06353365629911423, 0.06405746936798096, 0.06366757303476334, 0.06784793734550476, 0.06484751403331757, 0.07321573793888092, 0.06928813457489014, 0.07189634442329407, 0.05982948839664459], [0.0639602541923523, 0.06536619365215302, 0.06345970928668976, 0.06561338156461716, 0.0647890642285347, 0.06642547994852066, 0.06485749781131744, 0.06535132974386215, 0.0715189129114151, 0.06799386441707611, 0.06598794460296631, 0.06828077137470245, 0.07590865343809128, 0.06434038281440735, 0.0661466047167778]], 'p2h_attention': [[0.08047318458557129, 0.0836518406867981, 0.08973260223865509, 0.10442456603050232, 0.13734540343284607, 0.09600551426410675, 0.08500710874795914, 0.08348178118467331, 0.0935571938753128, 0.07456051558256149, 0.07176025956869125], [0.002723188139498234, 0.4152473211288452, 0.003227106295 ...

# %%
import numpy as np
labels = []
label_mapping = ['entailment','contradiction', 'neutral']
for d in set_129.to_dict(orient='records'):
  res = np.array(predictor.predict_json({"premise": d['Premise'],"hypothesis": d['Hypothesis']})).argmax()
  rev_res = np.array(predictor.predict_json({"premise": d['Hypothesis'] ,"hypothesis": d['Premise']})).argmax()
  if res == 0:
    labels.append("FE")
  elif res == 1:
    labels.append("Negation")
  else:
    if rev_res == 0:
      labels.append("RE")
    else:
      labels.append("Neutral")

# %%
len(labels)
# Out:
# 122

# %%
set_129['pair-classification-decomposable-attention-elmo'] = labels

# %%
set_129.head()
# Out:
#                                Premise                       Hypothesis  \
# 0     an old man is sitting in a field      a man is sitting in a field
# 1  every old man is sitting in a field      a man is sitting in a field
# 2     an old man is sitting in a field  every man is sitting in a field
# 3  every old man is sitting in a field  every man is sitting in a field
# 4   some old man is sitting in a field      a man is sitting in a field
#
#   Modifier Premise/Hypothesis/Both Part of Premise/Hypothesis Modified   M  \
# 0     NONE                    NONE                                NONE  FE
# 1    every                 premise                             subject  FE
# 2    every              hypothesis                             subject  RE
# 3    every                    Both                             subject  RE
# 4     some                 premise                             subject  FE
#
#              E   R   H   S Ground Truth  SICK_id nli-deberta-v3-base  \
# 0           FE  FE  FE  FE           FE      129                  FE
# 1           FE  FE  FE  FE           FE      129                  FE
# 2           RE  RE  RE  RE           RE      129             Neutral
# 3           RE  RE  RE  RE           RE      129                  FE
# 4  Equivalence  FE  FE  FE           FE      129                  FE
#
#   ynie/roberta-large-snli_mnli_fever_anli_R1_R2_R3-nli  \
# 0                                                 FE
# 1                                                 FE
# 2                                            Neutral
# 3                                                 FE
# 4                                                 FE
#
#   pair-classification-decomposable-attention-elmo
# 0                                              FE
# 1                                              FE
# 2                                              FE
# 3                                              FE
# 4                                              FE

# %%
set_129 = set_129.rename(columns={"label":"Ground Truth"})
set_129.head()
# Out:
#                                Premise                       Hypothesis  \
# 0     an old man is sitting in a field      a man is sitting in a field
# 1  every old man is sitting in a field      a man is sitting in a field
# 2     an old man is sitting in a field  every man is sitting in a field
# 3  every old man is sitting in a field  every man is sitting in a field
# 4   some old man is sitting in a field      a man is sitting in a field
#
#   Modifier Premise/Hypothesis/Both Part of Premise/Hypothesis Modified   M  \
# 0     NONE                    NONE                                NONE  FE
# 1    every                 premise                             subject  FE
# 2    every              hypothesis                             subject  RE
# 3    every                    Both                             subject  RE
# 4     some                 premise                             subject  FE
#
#              E   R   H   S Ground Truth  SICK_id nli-deberta-v3-base  \
# 0           FE  FE  FE  FE           FE      129                  FE
# 1           FE  FE  FE  FE           FE      129                  FE
# 2           RE  RE  RE  RE           RE      129             Neutral
# 3           RE  RE  RE  RE           RE      129                  FE
# 4  Equivalence  FE  FE  FE           FE      129                  FE
#
#   ynie/roberta-large-snli_mnli_fever_anli_R1_R2_R3-nli  \
# 0                                                 FE
# 1                                                 FE
# 2                                            Neutral
# 3                                                 FE
# 4                                                 FE
#
#   pair-classification-decomposable-attention-elmo
# 0                                              FE
# 1                                              FE
# 2                                              FE
# 3                                              FE
# 4                                              FE

# %%
set_129.to_excel(os.path.join(path,"sick1_annotations_nli_eval.xlsx"))

# %%
from pycm import *
cm = ConfusionMatrix(actual_vector=set_129['Ground Truth'].to_list(), predict_vector=set_129['nli-deberta-v3-base'].to_list())
cm.table
# Out:
# {'FE': {'FE': 73, 'Negation': 0, 'Neutral': 3, 'RE': 0},
#  'Negation': {'FE': 0, 'Negation': 1, 'Neutral': 0, 'RE': 0},
#  'Neutral': {'FE': 10, 'Negation': 9, 'Neutral': 20, 'RE': 0},
#  'RE': {'FE': 3, 'Negation': 1, 'Neutral': 2, 'RE': 0}}

# %%
cm.print_matrix()
# Out:
# Predict        FE             Negation       Neutral        RE
# Actual
# FE             73             0              3              0
#
# Negation       0              1              0              0
#
# Neutral        10             9              20             0
#
# RE             3              1              2              0

# %%
cm.stat(summary=True)
# Out:
# Overall Statistics :
#
# ACC Macro                                                         0.88525
# F1 Macro                                                          0.42323
# FPR Macro                                                         0.10637
# Kappa                                                             0.536
# Overall ACC                                                       0.77049
# PPV Macro                                                         None
# SOA1(Landis & Koch)                                               Moderate
# TPR Macro                                                         0.61834
# Zero-one Loss                                                     28
#
# Class Statistics :
#
# Classes                                                           FE            Negation      Neutral       RE
# ACC(Accuracy)                                                     0.86885       0.91803       0.80328       0.95082
# AUC(Area under the ROC curve)                                     0.83896       0.95868       0.72629       0.5
# AUCI(AUC value interpretation)                                    Very Good     Excellent     Good          Poor
# F1(F1 score - harmonic mean of precision and sensitivity)         0.90123       0.16667       0.625         0.0
# FN(False negative/miss/type 2 error)                              3             0             19            6
# FP(False positive/type 1 error/false alarm)                       13            10            5             0
# FPR(Fall-out or false positive rate)                              0.28261       0.08264       0.06024       0.0
# N(Condition negative)                                             46            121           83            116
# P(Condition positive or support)                                  76            1             39            6
# POP(Population)                                                   122           122           122           122
# PPV(Precision or positive predictive value)                       0.84884       0.09091       0.8           None
# TN(True negative/correct rejection)                               33            111           78            116
# TON(Test outcome negative)                                        36            111           97            122
# TOP(Test outcome positive)                                        86            11            25            0
# TP(True positive/hit)                                             73            1             20            0
# TPR(Sensitivity, recall, hit rate, or true positive rate)         0.96053       1.0           0.51282       0.0
