# %%
import matplotlib.pyplot as plt
import pylab

# %%
x_vanillaMarco = [0.9,
0.8,
0.7657894737,
0.7188888889,
0.7103448276,
0.6943977591,
0.6658119658,
0.6508417508,
0.632244898,
0.5987654321]

y_vanillaMarco = [29,
44,
59,
74,
89,
104,
119,
134,
149,
164]

x_gupta = [0.8050213675,
0.7433676654,
0.7402210884,
0.7489478114,
0.7489478114,
0.7489478114,
0.7489478114,
0.7489478114,
0.7471296296,
0.7471296296]

y_gupta = [61,
111,
121,
124,
124,
124,
124,
124,
125,
125]

# %%
markers = ['o', 'v', '*']
colours = ['c', 'crimson', 'chartreuse']

# %%
plt.scatter(y_vanillaMarco,x_vanillaMarco, marker=markers[2], s=20, c=colours[0])
plt.scatter(y_gupta,x_gupta, marker=markers[0], s=20, c=colours[1])
plt.plot(y_vanillaMarco,x_vanillaMarco,c=colours[0])
plt.plot(y_gupta,x_gupta,c=colours[1])
plt.grid()
plt.show()
p1 = plt.Rectangle((0, 0), 0.1, 0.1, fc=colours[0])
p2 = plt.Rectangle((0, 0), 0.1, 0.1, fc=colours[1])

plt.legend((p1, p2), ('Vanilla', 'Entity-Classifier'), loc='best')
plt.xlabel('Throughput')

# Sets y-axis
plt.ylabel('Precision')

# Sets title
plt.title("Throughput vs. Precision")
